# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("PrePlacement.csv")
data
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
data.drop("sl_no",inplace=True,axis=1)

# %%
data
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
data.columns
# Out:
# Index(['gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s', 'degree_p',
#        'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p', 'status',
#        'salary'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
#same group and different conditions
from scipy.stats import ttest_rel
#data=data.dropna()
male=data[data["gender"]=="M"]["hsc_p"]
male1=data[data["gender"]=="M"]["ssc_p"]
ttest_rel(male,male1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_692\494507610.py in <module>
#       2 from scipy.stats import ttest_rel
#       3 #data=data.dropna()
# ----> 4 male=data[data["gender"]=="M"]["hsc_p"]
#       5 male1=data[data["gender"]=="M"]["ssc_p"]
#       6 ttest_rel(male,male1)
#
# NameError: name 'data' is not defined

# %%
#Different group and one condition
from scipy.stats import ttest_ind
specialisation = dataset[dataset['specialisation']=='Mkt&HR']["salary"]
degree_t = dataset[dataset['degree_t']=='Sci&Tech']["salary"]
ttest_ind(specialisation,degree_t)

# %%
#statement:Test whether ssc_p male and hsc_p male are same
#Null Hyposthesis: There is no similarity 10th pass mark of male and 12th pass mark of male
#Reject null hyposthesis if the pvalue is less that 0.05%
# Accept null- hyposthesis and reject- Alternate hypothesis

# %% [markdown]
# # ANOVA - Analysis of Variance -One way classification

# %%
import scipy.stats as stats
stats.f_oneway(data["ssc_p"],data["hsc_p"],data["degree_p"])
# Hypothesis testing- As the pvalue is greater than 0.05 we can accept alternate hypothesis and reject null hypothesis
# Out:
# F_onewayResult(statistic=0.695991304348204, pvalue=0.49895574725815317)

# %% [markdown]
# # Two way classification

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
two_way=ols('sl_no~ssc_p+hsc_p+degree_p+ssc_p:hsc_p:degree_p',data=data).fit()
two=sm.stats.anova_lm(two_way,type=2)
two
# Out:
#                          df         sum_sq      mean_sq         F    PR(>F)
# ssc_p                   1.0    5058.655954  5058.655954  1.303616  0.254854
# hsc_p                   1.0    2853.534158  2853.534158  0.735356  0.392130
# degree_p                1.0    1781.372511  1781.372511  0.459060  0.498809
# ssc_p:hsc_p:degree_p    1.0    3585.540655  3585.540655  0.923994  0.337534
# Residual              210.0  814900.896721  3880.480461       NaN       NaN

# %%
#Result of Two way classification
#statement:There is significant differnce between ssc_p,hsc_p,degree_P
#Interaction =ssc_p*hsc_p*degree_p
#Ho=There is no significant differnce betwween ssc_p,hsc_p,degree_P
#H1=There is significant differnce betwween ssc_p,hsc_p,degree_P
